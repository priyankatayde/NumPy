# %%
import pandas as pd

# %%
df=pd.read_excel("imbd_1000.xlsx")
df
# Out:
#              star_rating title  \
# 0                      0   9.3
# 1                      1   9.2
# 2                      2   9.1
# 3                      3     9
# 4                      4   8.9
# ..                   ...   ...
# 57                   975   7.4
# 58                   976   7.4
# 59                   977   7.4
# 60                   978   7.4
# 61  979 rows × 6 columns   NaN
#
#                                      content_rating  genre   duration  \
# 0                          The Shawshank Redemption      R      Crime
# 1                                     The Godfather      R      Crime
# 2                            The Godfather: Part II      R      Crime
# 3                                   The Dark Knight  PG-13     Action
# 4                                      Pulp Fiction      R      Crime
# ..                                              ...    ...        ...
# 57                      Back to the Future Part III     PG  Adventure
# ...

# %%
df=pd.read_excel("imbd_1000.xlsx")
df
# Out:
#              star_rating title  \
# 0                      0   9.3
# 1                      1   9.2
# 2                      2   9.1
# 3                      3     9
# 4                      4   8.9
# ..                   ...   ...
# 57                   975   7.4
# 58                   976   7.4
# 59                   977   7.4
# 60                   978   7.4
# 61  979 rows × 6 columns   NaN
#
#                                      content_rating  genre   duration  \
# 0                          The Shawshank Redemption      R      Crime
# 1                                     The Godfather      R      Crime
# 2                            The Godfather: Part II      R      Crime
# 3                                   The Dark Knight  PG-13     Action
# 4                                      Pulp Fiction      R      Crime
# ..                                              ...    ...        ...
# 57                      Back to the Future Part III     PG  Adventure
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     62 non-null     object
#  1   title           61 non-null     object
#  2   content_rating  61 non-null     object
#  3   genre           61 non-null     object
#  4   duration        61 non-null     object
#  5   actors_list     61 non-null     object
#  6   Unnamed: 6      61 non-null     object
# dtypes: object(7)
# memory usage: 3.5+ KB

# %%
df.describe()
# Out:
#        star_rating  title content_rating genre duration  actors_list  \
# count           62   61.0             61    61       61           61
# unique          62   10.0             61     9       11           46
# top            ...    7.4            ...     R    Drama          118
# freq             1   30.0              1    28       15            3
#
#                                                Unnamed: 6
# count                                                  61
# unique                                                 60
# top     [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# freq                                                    2

# %%
result=df.head(10)
print(result)
# Out:
#   star_rating title                                 content_rating      genre  \
# 0           0   9.3                       The Shawshank Redemption          R
# 1           1   9.2                                  The Godfather          R
# 2           2   9.1                         The Godfather: Part II          R
# 3           3     9                                The Dark Knight      PG-13
# 4           4   8.9                                   Pulp Fiction          R
# 5           5   8.9                                   12 Angry Men  NOT RATED
# 6           6   8.9                 The Good, the Bad and the Ugly  NOT RATED
# 7           7   8.9  The Lord of the Rings: The Return of the King      PG-13
# 8           8   8.9                               Schindler's List          R
# 9           9   8.9                                     Fight Club          R
#
#     duration actors_list                                         Unnamed: 6
# ...

# %%
result=df.tail(10)
print(result)
# Out:
#              star_rating title  \
# 52                   970   7.4
# 53                   971   7.4
# 54                   972   7.4
# 55                   973   7.4
# 56                   974   7.4
# 57                   975   7.4
# 58                   976   7.4
# 59                   977   7.4
# 60                   978   7.4
# 61  979 rows × 6 columns   NaN
#
#                                      content_rating  genre   duration  \
# 52                                      Wonder Boys      R      Drama
# 53                               Death at a Funeral      R     Comedy
# 54                                   Blue Valentine  NC-17      Drama
# 55                            The Cider House Rules  PG-13      Drama
# 56                                          Tootsie     PG     Comedy
# 57                      Back to the Future Part III     PG  Adventure
# 58  Master and Commander: The Far Side of the World  PG-13     Action
# ...

# %%
df.iloc[100:200]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list, Unnamed: 6]
# Index: []

# %%
df.set_index("title",inplace=True)
df
# Out:
#                 star_rating                                   content_rating  \
# title
# 9.3                       0                         The Shawshank Redemption
# 9.2                       1                                    The Godfather
# 9.1                       2                           The Godfather: Part II
# 9.0                       3                                  The Dark Knight
# 8.9                       4                                     Pulp Fiction
# ...                     ...                                              ...
# 7.4                     975                      Back to the Future Part III
# 7.4                     976  Master and Commander: The Far Side of the World
# 7.4                     977                                      Poltergeist
# 7.4                     978                                      Wall Street
# NaN    979 rows × 6 columns                                              NaN
#
# ...

# %%
df.loc[df["star_rating"]>7]

# %%
arr=df.loc[df["genre"]=='Crime']
arr
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list, Unnamed: 6]
# Index: []

# %%
arr.shape[0]
# Out:
# 0
